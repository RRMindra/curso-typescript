// %% [markdown]
// # 🧪 Módulo 11 — Ejercicios sobre `.d.ts`, tipos externos y ampliación de librerías
//
// En estos ejercicios aprenderás a:
//
// - Crear archivos `.d.ts`
// - Tipar librerías JavaScript internas
// - Declarar módulos sin tipos
// - Extender tipos globales
// - Ampliar tipos de librerías existentes
//
// 👉 El notebook **solo genera directorios y archivos vacíos**.
//
// 👉 **TÚ** deberás copiar en esos archivos el código que aparece en cada ejercicio.
//
//
// ---
// Todos los archivos se guardarán en:
//
// ```
// ./modulo11/ejercicios/
// ```
//
// ---

// %% [markdown]
// # 🧩 Ejercicio 1 — Crear tu primer `.d.ts`
//
// Vas a crear un archivo de definición de tipos para una librería JS muy simple.
//
// ## 📄 Archivos que se generarán
// - `saludo.js` (vacío)
// - `saludo.d.ts` (vacío)
//
// ## ✏️ Código que debes pegar en `saludo.js`:
// ```js
// export function saludar(nombre) {
//   return `Hola, ${nombre}`;
// }
// ```
//
// ## ✏️ Código que debes pegar en `saludo.d.ts`:
// ```ts
// export function saludar(nombre: string): string;
// ```
//
// Luego importa la función desde TypeScript y comprueba que el tipado funciona.

// %%
// Crear directorio base
await Deno.mkdir("modulo11/ejercicios", { recursive: true });

// Crear archivos vacíos
await Deno.writeTextFile("modulo11/ejercicios/saludo.js", "");
await Deno.writeTextFile("modulo11/ejercicios/saludo.d.ts", "");

console.log("Archivos creados: saludo.js, saludo.d.ts");

// %% [markdown]
// ---
// # 🧩 Ejercicio 2 — Declarar un módulo externo sin tipos
//
// Simula una librería sin tipos y declara un módulo manualmente.
//
// ## 📄 Archivos creados:
// - `miLibreria.js` (vacío)
// - `global.d.ts` (vacío)
//
// ## ✏️ Código que debes pegar en `miLibreria.js`:
// ```js
// export function generarNumero() {
//   return Math.floor(Math.random() * 100);
// }
// ```
//
// ## ✏️ Código que debes pegar en `global.d.ts`:
// ```ts
// declare module "miLibreria";
// ```
//
// Ahora importa `miLibreria` desde un archivo TypeScript y comprueba que compila sin errores.

// %%
// Crear archivos vacíos para el ejercicio 2
await Deno.writeTextFile("modulo11/ejercicios/miLibreria.js", "");
await Deno.writeTextFile("modulo11/ejercicios/global.d.ts", "");

console.log("Archivos creados: miLibreria.js, global.d.ts");

// %% [markdown]
// ---
// # 🧩 Ejercicio 3 — Extender tipos globales
//
// Vas a añadir tipado extra al objeto `Window`.
//
// ## 📄 Archivo creado:
// - `global-extend.d.ts` (vacío)
//
// ## ✏️ Código que debes pegar en `global-extend.d.ts`:
// ```ts
// declare global {
//   interface Window {
//     version: string;
//   }
// }
// ```
//
// ## ✔ Después:
// Escribe un archivo TS (manual) donde hagas:
//
// ```ts
// window.version = "1.0.0";
// console.log(window.version);
// ```

// %%
// Crear archivo vacío para ejercicio 3
await Deno.writeTextFile("modulo11/ejercicios/global-extend.d.ts", "");

console.log("Archivo creado: global-extend.d.ts");

// %% [markdown]
// ---
// # 🧩 Ejercicio 4 — Extender tipos de una librería
//
// Amplía una librería existente añadiendo nuevas propiedades a sus tipos.
//
// Simularemos una versión simplificada de Axios.
//
//
// ## 📄 Archivos creados:
// - `axios.js` (vacío)
// - `axios-ext.d.ts` (vacío)
//
//
// ## ✏️ Código para `axios.js`:
// ```js
// export function request(config) {
//   return { ok: true, config };
// }
// ```
//
// ## ✏️ Código para `axios-ext.d.ts`:
// ```ts
// import "./axios.js";
//
// declare module "./axios.js" {
//   export interface AxiosConfig {
//     retry?: number;
//   }
// }
// ```
//
// 👉 Luego usa la propiedad `retry` desde TypeScript.

// %%
// Crear archivos vacíos para ejercicio 4
await Deno.writeTextFile("modulo11/ejercicios/axios.js", "");
await Deno.writeTextFile("modulo11/ejercicios/axios-ext.d.ts", "");

console.log("Archivos creados: axios.js, axios-ext.d.ts");

// %% [markdown]
// ---
// # 🧩 Ejercicio 5 — Crear tipado completo para una mini librería interna
//
// Aquí crearás una pequeña librería matemática en JS y la tiparás usando un `.d.ts`.
//
// ## 📄 Archivos creados:
// - `math.js` (vacío)
// - `math.d.ts` (vacío)
//
// ## ✏️ Código para `math.js`:
// ```js
// export function doble(x) {
//   return x * 2;
// }
//
// export function triple(x) {
//   return x * 3;
// }
// ```
//
// ## ✏️ Código para `math.d.ts`:
// ```ts
// export function doble(x: number): number;
// export function triple(x: number): number;
// ```

// %%
// Crear archivos vacíos para ejercicio 5
await Deno.writeTextFile("modulo11/ejercicios/math.js", "");
await Deno.writeTextFile("modulo11/ejercicios/math.d.ts", "");

console.log("Archivos creados: math.js, math.d.ts");

// %% [markdown]
// ---
// # 🎉 Fin de los Ejercicios del Módulo 11
//
// Has practicado:
// - creación de definiciones de tipos
// - declaración de módulos externos
// - ampliación del entorno global
// - extensión de librerías existentes
// - tipado de librerías internas en JavaScript
//
// Ahora puedes continuar con el **Laboratorio del Módulo 11**.
