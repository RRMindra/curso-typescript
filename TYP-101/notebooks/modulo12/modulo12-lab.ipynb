// %% [markdown]
// # 🧪 Laboratorio — Módulo 12: Proyecto real con TS + Build + Webpack
//
// Este es el **laboratorio final** del curso.
//
// Aquí NO ejecutamos código en el notebook; este documento es una **guía paso a paso** para tu Codespace.
//
// ---
// ## 🎯 Objetivo general
//
// Construir un proyecto real de TypeScript con:
// - `src/` y `dist/`
// - `tsconfig.json` completo
// - Decoradores reales (`experimentalDecorators`)
// - Compilación TS → JS
// - Webpack + ts-loader
// - Proyecto final: **Task Manager con decoradores**
//
// Todo esto se realiza **fuera del notebook**, en tu terminal.

// %% [markdown]
// # 🧱 Paso 1 — Crear estructura inicial
//
// En tu Codespace ejecuta:
//
// ```bash
// mkdir ts-project
// cd ts-project
//
// mkdir src dist
// npm init -y
// ```
//
// Tu estructura queda:
//
// ```
// ts-project/
//   package.json
//   src/
//   dist/
// ```

// %% [markdown]
// # 🧱 Paso 2 — Instalar dependencias
//
// Ejecuta:
//
// ```bash
// npm install typescript ts-node --save-dev
// npm install webpack webpack-cli ts-loader --save-dev
// ```
//
// ✔ Ya tienes todo para compilar y empaquetar.

// %% [markdown]
// # 🧱 Paso 3 — Crear `tsconfig.json`
//
// 📁 Archivo: `tsconfig.json`
//
// ```json
// {
//   "compilerOptions": {
//     "target": "ES2020",
//     "module": "ESNext",
//     "rootDir": "src",
//     "outDir": "dist",
//     "strict": true,
//     "noImplicitAny": true,
//     "experimentalDecorators": true,
//     "emitDecoratorMetadata": false,
//     "moduleResolution": "Node",
//     "esModuleInterop": true,
//     "skipLibCheck": true
//   },
//   "include": ["src"]
// }
// ```

// %% [markdown]
// # 🧱 Paso 4 — Crear un decorador real
//
// 📁 Archivo: `src/decorators/log.ts`
//
// ```ts
// export function Log(message: string) {
//   return function (target: any, propertyKey?: string, descriptor?: PropertyDescriptor) {
//     if (descriptor) {
//       const original = descriptor.value;
//       descriptor.value = function (...args: unknown[]) {
//         console.log(`LOG (${message}):`, ...args);
//         return original.apply(this, args);
//       };
//     }
//   };
// }
// ```
//
// ✔ Este decorador modifica métodos reales.

// %% [markdown]
// # 🧱 Paso 5 — Modelo del proyecto: `Task`
//
// 📁 Archivo: `src/models/Task.ts`
//
// ```ts
// export interface TaskProps {
//   id: string;
//   titulo: string;
//   completada: boolean;
// }
//
// export class Task {
//   id: string;
//   titulo: string;
//   completada: boolean;
//
//   constructor(props: TaskProps) {
//     this.id = props.id;
//     this.titulo = props.titulo;
//     this.completada = props.completada;
//   }
// }
// ```

// %% [markdown]
// # 🧱 Paso 6 — Servicio con decoradores
//
// 📁 Archivo: `src/services/TaskService.ts`
//
// ```ts
// import { Task } from "../models/Task";
// import { Log } from "../decorators/log";
//
// export class TaskService {
//   private tareas: Task[] = [];
//
//   @Log("Crear tarea")
//   crear(titulo: string): Task {
//     const nueva = new Task({
//       id: crypto.randomUUID(),
//       titulo,
//       completada: false,
//     });
//     this.tareas.push(nueva);
//     return nueva;
//   }
//
//   @Log("Completar tarea")
//   completar(id: string): Task | undefined {
//     const t = this.tareas.find(t => t.id === id);
//     if (t) t.completada = true;
//     return t;
//   }
//
//   listar(): Task[] {
//     return [...this.tareas];
//   }
// }
// ```

// %% [markdown]
// # 🧱 Paso 7 — Punto de entrada
//
// 📁 Archivo: `src/index.ts`
//
// ```ts
// import { TaskService } from "./services/TaskService";
//
// const service = new TaskService();
//
// const t1 = service.crear("Preparar curso");
// const t2 = service.crear("Enviar documentación");
//
// service.completar(t1.id);
//
// console.log("Estado final:", service.listar());
// ```
//
// ✔ Ya tienes una pequeña aplicación TS real.

// %% [markdown]
// # 🧱 Paso 8 — Configurar Webpack
//
// 📁 Archivo: `webpack.config.js`
//
// ```js
// const path = require("path");
//
// module.exports = {
//   entry: "./src/index.ts",
//   module: {
//     rules: [
//       { test: /\.ts$/, use: "ts-loader", exclude: /node_modules/ }
//     ]
//   },
//   resolve: { extensions: [".ts", ".js"] },
//   output: {
//     filename: "bundle.js",
//     path: path.resolve(__dirname, "dist")
//   },
//   mode: "development"
// };
// ```

// %% [markdown]
// # 🧱 Paso 9 — Comandos útiles
//
// ### ▶ Compilar TS → JS
// ```bash
// npx tsc
// ```
//
// ### ▶ Ejecutar con ts-node
// ```bash
// npx ts-node src/index.ts
// ```
//
// ### ▶ Generar bundle con webpack
// ```bash
// npx webpack
// ```
//
// ### Resultado esperado en `dist/`:
// - `index.js` (compilado por tsc)
// - `bundle.js` (generado por webpack)

// %% [markdown]
// ---
// ## 🧩 Reflexión
//
// - ¿Te resultó más claro el build con TS real?
// - ¿Dónde surgieron dudas con decoradores reales?
// - ¿Qué parte debería mejorarse o ampliarse según tu experiencia?
//
// ---
// 🎉 **Laboratorio del Módulo 12 completado**
//
// Has construido un proyecto TS profesional con:
// - Decoradores reales
// - tsconfig completo
// - webpack + ts-loader
// - estructura modular
// - build a JS
//
// Este es el proyecto final base para el cierre del curso.
